# %%
import whisper
import torch
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load model (choose "tiny", "base", "small", "medium", or "large")
model = whisper.load_model("medium")
print("Whisper model loaded")
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:30<00:00, 50.9MiB/s]
# Whisper model loaded

# %%
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

# “I need an eco-friendly stainless-steel cleaner under $15”

# Sampling frequency
freq = 44100

# Recording duration
duration = 6

# Start recorder with the given values 
# of duration and sample frequency
recording = sd.rec(int(duration * freq), 
                   samplerate=freq, channels=1)

# Record audio for the given number of seconds
sd.wait()

# # This will convert the NumPy array to an audio
# # file with the given sampling frequency
# write("./recording/recording0.wav", freq, recording)

# Convert the NumPy array to audio file
wv.write("./recording/recording0.wav", recording, freq, sampwidth=2)

# %%
audio_path = "./recording/recording0.wav"

# Load audio
audio, sr = librosa.load(audio_path, sr=16000)

# %%
mel = whisper.log_mel_spectrogram(torch.tensor(audio))

# %%
result = model.transcribe(audio_path)
print(" Transcription:")
print(result["text"])
# Out:
# /opt/anaconda3/envs/genai/lib/python3.12/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Transcription:
#  I need an eco-friendly stainless steel cleaner under $15.
