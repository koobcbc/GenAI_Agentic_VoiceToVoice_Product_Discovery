# %%
import chromadb

client = chromadb.PersistentClient(
    path="/Users/yeochanyoun/Desktop/uchic/courses/Autumn2025/Gen AI II/final/GenAI_Agentic_VoiceToVoice_Product_Discovery/agents/tools/data")
collection = client.get_collection("products_toys")

# %%
import os

test_path = "/Users/.../data/test_write.txt"

with open(test_path, "w") as f:
    f.write("test")

# %%
results = collection.query(
    query_texts="test",
    n_results=5
)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = collection.query(
#       2     query_texts="test",
#       3     n_results=5
#       4 )
#
# File ~/Desktop/uchic/courses/Autumn2025/Gen AI II/final/GenAI_Agentic_VoiceToVoice_Product_Discovery/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:229, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     193 """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     194
#     195 Args:
#    (...)    214
#     215 """
#     217 query_request = self._validate_and_prepare_query_request(
#     218     query_embeddings=query_embeddings,
#     219     query_texts=query_texts,
#    (...)    226     include=include,
#     227 )
# ...
